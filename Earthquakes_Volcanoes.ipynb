# %%
import pandas as pd
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %%
#SET VOLCANO PATH, ALL VOLCANO DATA
Volcanoes_df = Path("Resources/The_Volcanoes_Of_Earth.csv")
Volcanoes_df = pd.read_csv(Volcanoes_df)

# %%
Volcanoes_df.head()
# Out:
#       Volcano_Name                                      Volcano_Image  \
# 0              Abu  https://volcano.si.edu/gallery/photos/GVP-0895...
# 1       Acamarachi  https://volcano.si.edu/gallery/photos/GVP-0688...
# 2       Acatenango  https://volcano.si.edu/gallery/photos/GVP-0788...
# 3  Acigol-Nevsehir  https://volcano.si.edu/includes/images/noimage...
# 4            Adams  https://volcano.si.edu/gallery/photos/GVP-0281...
#
#         Volcano_Type        Country                          Region  \
# 0          Shield(s)          Japan         Japan, Taiwan, Marianas
# 1      Stratovolcano          Chile                   South America
# 2  Stratovolcano(es)      Guatemala      México and Central America
# 3            Caldera         Turkey  Mediterranean and Western Asia
# 4      Stratovolcano  United States          Canada and Western USA
#
#                                Subregion epoch_period  \
# 0                                 Honshu     holocene
# ...

# %%
#DETERMINE DATA TYPES
Volcanoes_df.dtypes
# Out:
# Volcano_Name                object
# Volcano_Image               object
# Volcano_Type                object
# Country                     object
# Region                      object
# Subregion                   object
# epoch_period                object
# Last_Eruption               object
# Summit_and_Elevatiuon       object
# Latitude                    object
# Longitude                   object
# population_within_5km      float64
# population_within_10km     float64
# population_within_30km     float64
# population_within_100km    float64
# dtype: object

# %%
#SETTING NEW VARIABLE FOR VOLCANO NAMES AND BASIC STATS, 
#SETTING IT UP TO COMPARE TO EARTHQUAKES
Volcano_Names = Path("Resources/The_Volcanoes_Of_Earth.csv")
Volcano_Names = pd.read_csv(Volcano_Names, index_col="Volcano_Name")
Volcano_Names.head()
# Out:
#                                                      Volcano_Image  \
# Volcano_Name
# Abu              https://volcano.si.edu/gallery/photos/GVP-0895...
# Acamarachi       https://volcano.si.edu/gallery/photos/GVP-0688...
# Acatenango       https://volcano.si.edu/gallery/photos/GVP-0788...
# Acigol-Nevsehir  https://volcano.si.edu/includes/images/noimage...
# Adams            https://volcano.si.edu/gallery/photos/GVP-0281...
#
#                       Volcano_Type        Country  \
# Volcano_Name
# Abu                      Shield(s)          Japan
# Acamarachi           Stratovolcano          Chile
# Acatenango       Stratovolcano(es)      Guatemala
# Acigol-Nevsehir            Caldera         Turkey
# Adams                Stratovolcano  United States
#
#                                          Region  \
# Volcano_Name
# Abu                     Japan, Taiwan, Marianas
# Acamarachi                        South America
# Acatenango           México and Central America
# ...

# %%
#DETERMINING VOLCANO NAMES 
Volcano_Names = Volcano_Names[['Volcano_Type', 'Country', 'Last_Eruption']]
Volcano_Names.head()
# Out:
#                       Volcano_Type        Country                Last_Eruption
# Volcano_Name
# Abu                      Shield(s)          Japan                     6850 BCE
# Acamarachi           Stratovolcano          Chile  Unknown - Evidence Credible
# Acatenango       Stratovolcano(es)      Guatemala                      1972 CE
# Acigol-Nevsehir            Caldera         Turkey                     2080 BCE
# Adams                Stratovolcano  United States                       950 CE

# %%
Volcano_Names.tail()
# Out:
#                            Volcano_Type   Country Last_Eruption
# Volcano_Name
# Zarechny                     Caldera(s)    Russia   Pleistocene
# Zenikame                      Submarine     Japan   Pleistocene
# Zheltiy                   Stratovolcano    Russia   Pleistocene
# Zhupanovskiye Vostriyaky  Stratovolcano    Russia   Pleistocene
# Zikwala                   Stratovolcano  Ethiopia   Pleistocene

# %%
Volcano_Names['Country'].value_counts()
# Out:
# Country
# United States            324
# Japan                    283
# Russia                   258
# Indonesia                213
# Chile                    158
#                         ...
# Saint Lucia                1
# Jordan                     1
# Sao Tome and Principe      1
# Pakistan                   1
# Senegal                    1
# Name: count, Length: 96, dtype: int64

# %%
###ADDING EARTHQUAKES

# %%
Earthquakes_df = Path("Resources/earthquake_1995-2023.csv")
Earthquakes_df = pd.read_csv(Earthquakes_df)

# %%
Earthquakes_df.head()
# Out:
#                                       title  magnitude         date_time  cdi  \
# 0          M 6.5 - 42 km W of Sola, Vanuatu        6.5  16-08-2023 12:47    7
# 1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19-07-2023 00:22    8
# 2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17-07-2023 03:05    7
# 3     M 7.2 - 98 km S of Sand Point, Alaska        7.2  16-07-2023 06:48    6
# 4                  M 7.3 - Alaska Peninsula        7.3  16-07-2023 06:48    0
#
#    mmi   alert  tsunami  sig net  nst      dmin    gap magType    depth  \
# 0    4   green        0  657  us  114  7.177000   25.0     mww  192.955
# 1    6  yellow        0  775  us   92  0.679000   40.0     mww   69.727
# 2    5   green        0  899  us   70  1.634000   28.0     mww  171.371
# 3    6   green        1  860  us  173  0.907000   36.0     mww   32.571
# 4    5     NaN        1  820  at   79  0.879451  172.8      Mi   21.000
#
# ...

# %%
#DETERMINE DATA TYPES
Earthquakes_df.dtypes
# Out:
# title         object
# magnitude    float64
# date_time     object
# cdi            int64
# mmi            int64
# alert         object
# tsunami        int64
# sig            int64
# net           object
# nst            int64
# dmin         float64
# gap          float64
# magType       object
# depth        float64
# latitude     float64
# longitude    float64
# location      object
# continent     object
# country       object
# dtype: object

# %%
#SETTING NEW VARIABLE FOR EARTHQUAKE TITLES AND BASIC STATS, 
#SETTING IT UP TO COMPARE TO EARTHQUAKES
EQ_Titles = Path("Resources/earthquake_1995-2023.csv")
EQ_Titles = pd.read_csv(EQ_Titles, index_col="title")
EQ_Titles.head()
# Out:
#                                           magnitude         date_time  cdi  \
# title
# M 6.5 - 42 km W of Sola, Vanuatu                6.5  16-08-2023 12:47    7
# M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19-07-2023 00:22    8
# M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17-07-2023 03:05    7
# M 7.2 - 98 km S of Sand Point, Alaska           7.2  16-07-2023 06:48    6
# M 7.3 - Alaska Peninsula                        7.3  16-07-2023 06:48    0
#
#                                           mmi   alert  tsunami  sig net  nst  \
# title
# M 6.5 - 42 km W of Sola, Vanuatu            4   green        0  657  us  114
# M 6.5 - 43 km S of Intipucá, El Salvador    6  yellow        0  775  us   92
# M 6.6 - 25 km ESE of Loncopué, Argentina    5   green        0  899  us   70
# M 7.2 - 98 km S of Sand Point, Alaska       6   green        1  860  us  173
# M 7.3 - Alaska Peninsula                    5     NaN        1  820  at   79
#
# ...

# %%
#DETERMINING EARTHQUAKE TITLES
EQ_Titles = EQ_Titles[['country', 'date_time']]
EQ_Titles.head()
# Out:
#                                             country         date_time
# title
# M 6.5 - 42 km W of Sola, Vanuatu            Vanuatu  16-08-2023 12:47
# M 6.5 - 43 km S of Intipucá, El Salvador        NaN  19-07-2023 00:22
# M 6.6 - 25 km ESE of Loncopué, Argentina  Argentina  17-07-2023 03:05
# M 7.2 - 98 km S of Sand Point, Alaska           NaN  16-07-2023 06:48
# M 7.3 - Alaska Peninsula                        NaN  16-07-2023 06:48

# %%
#CONCATTING EARTHQUAKES AND VOLCANOES
EQs_Vs = pd.concat([EQ_Titles, Volcano_Names], axis="columns", join="inner")
EQs_Vs
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[53], line 2
#       1 #CONCATTING EARTHQUAKES AND VOLCANOES
# ----> 2 EQs_Vs = pd.concat([EQ_Titles, Volcano_Names], axis="columns", join="inner")
#       3 EQs_Vs
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/concat.py:385, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     370     copy = False
#     372 op = _Concatenator(
#     373     objs,
#     374     axis=axis,
#    (...)
#     382     sort=sort,
#     383 )
# --> 385 return op.get_result()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/concat.py:612, in _Concatenator.get_result(self)
#     610         obj_labels = obj.axes[1 - ax]
#     611         if not new_labels.equals(obj_labels):
# --> 612             indexers[ax] = obj_labels.get_indexer(new_labels)
# ...
